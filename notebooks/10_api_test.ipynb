# %%
import requests
import json

BASE_URL = "http://localhost:8000"

def pretty(response):
    """Print formatted JSON response."""
    print(f"Status: {response.status_code}")
    print(json.dumps(response.json(), indent=2))

# %%
resp = requests.get(f"{BASE_URL}/health")
pretty(resp)
# Out:
# Status: 200
# {
#   "status": "ok",
#   "database": "ok",
#   "model": "ok",
#   "version": "1.0.0"
# }

# %%
resp = requests.get(f"{BASE_URL}/analyze/RELIANCE.NS")
pretty(resp)
# Out:
# Status: 200
# {
#   "ticker": "RELIANCE.NS",
#   "company_name": "Reliance Industries",
#   "date": "2026-06-19",
#   "probability_up": 0.3017,
#   "probability_down": 0.6983,
#   "confidence": "medium",
#   "top_features": [
#     {
#       "feature": "macd_hist",
#       "value": 6.1396,
#       "shap_value": -1.6362,
#       "direction": "bearish",
#       "magnitude": 1.6362
#     },
#     {
#       "feature": "macd_signal",
#       "value": -16.4423,
#       "shap_value": 0.996,
#       "direction": "bullish",
#       "magnitude": 0.996
#     },
#     {
#       "feature": "price_vs_sma50",
#       "value": -0.0267,
#       "shap_value": -0.441,
#       "direction": "bearish",
#       "magnitude": 0.441
#     },
#     {
#       "feature": "volume_ratio",
#       "value": 1.4409,
#       "shap_value": 0.421,
#       "direction": "bullish",
#       "magnitude": 0.421
#     },
#     {
#       "feature": "sma_20",
#       "value": 1309.3093,
#       "shap_value": -0.3773,
#       "direction": "bearish",
#       "magnitude": 0.3773
#     }
#   ],
#   "horizon_days": 10,
#   "training_samples": 352,
#   "error": null
# }

# %%
resp = requests.get(f"{BASE_URL}/explain/TCS.NS")
pretty(resp)
# Out:
# Status: 200
# {
#   "ticker": "TCS.NS",
#   "date": "2026-06-19",
#   "probability_up": 0.2195,
#   "confidence": "high",
#   "explanation": "Our model suggests that Tata Consultancy Services (TCS) is more likely to see a price decline over the next 10 trading days.\n\nThe primary drivers for this outlook are the [50-day moving average], which shows the stock\u2019s medium-term trend is currently downward, and the [MACD momentum histogram], which indicates that the speed of the stock's recent price movement is slowing down. \n\nHowever, there are some conflicting signals: trading volume is currently high, and other momentum indicators suggest the stock is sitting at a level that some traders consider \"cheap\" relative to its recent range. These factors suggest some underlying interest, even while the broader trend remains weak.\n\nOur model has high confidence in this analysis. Please remember that stock market predictions are probabilistic\u2014even a high-confidence signal is just a mathematical estimate and not a guarantee of future performance.",
#   "word_count": 138,
#   "error": null
# }

# %%
resp = requests.post(
    f"{BASE_URL}/ask",
    json={"question": "What does a Bollinger Band squeeze mean?",
          "ticker": "RELIANCE.NS"}
)
pretty(resp)
# Out:
# Status: 200
# {
#   "question": "What does a Bollinger Band squeeze mean?",
#   "answer": "A Bollinger Band squeeze occurs when the three lines drawn around a stock's price chart become very narrow. This indicates that the stock's volatility is currently unusually low. \n\nHistorically, these squeezes are often followed by large price moves. However, it is important to note that the direction of that move remains unknown until it actually begins. InvestIQ monitors the band width specifically to detect when these squeeze conditions are occurring for stocks like RELIANCE.NS.",
#   "sources": [
#     "What are Bollinger Bands?"
#   ],
#   "used_rag": true,
#   "error": null
# }

# %%
resp = requests.get(f"{BASE_URL}/overview")
pretty(resp)
# Out:
# Status: 200
# {
#   "date": "2026-07-12",
#   "stocks": [
#     {
#       "ticker": "RELIANCE.NS",
#       "date": "2026-07-03",
#       "close": 1304.0,
#       "rsi": 46.276766,
#       "macd_hist": 1.274513,
#       "sma_50": 1339.273972,
#       "trend": "Below SMA50"
#     },
#     {
#       "ticker": "TCS.NS",
#       "date": "2026-07-03",
#       "close": 2093.5,
#       "rsi": 43.836352,
#       "macd_hist": -0.389361,
#       "sma_50": 2241.809138,
#       "trend": "Below SMA50"
#     },
#     {
#       "ticker": "INFY.NS",
#       "date": "2026-07-03",
#       "close": 1047.2,
#       "rsi": 42.918931,
#       "macd_hist": -3.589512,
#       "sma_50": 1121.448744,
#       "trend": "Below SMA50"
#     },
#     {
#       "ticker": "HDFCBANK.NS",
#       "date": "2026-07-03",
#       "close": 801.05,
#       "rsi": 65.411275,
#       "macd_hist": 2.435348,
#       "sma_50": 762.600369,
#       "trend": "Above SMA50"
#     },
#     {
#       "ticker": "WIPRO.NS",
#       "date": "2026-07-03",
#       "close": 176.08,
#       "rsi": 39.916006,
#       "macd_hist": 0.086284,
#       "sma_50": 190.829399,
#       "trend": "Below SMA50"
#     }
#   ]
# }
